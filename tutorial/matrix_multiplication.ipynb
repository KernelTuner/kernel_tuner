# %% [markdown]
# # Matrix multiplication
#
# Matrix multiplication is one of the most well-known linear algebra algorithms, and frequently used to demonstrate the high-performance computing capabilities of GPUs. As such, an example using matrix multiplication could not be left out. A naive CUDA kernel for a square matrix multiplication is:

# %%
# %load matmul_naive.cu
#define WIDTH 4096

__global__ void matmul_kernel(float *C, float *A, float *B) {
    int x = blockIdx.x * block_size_x + threadIdx.x;
    int y = blockIdx.y * block_size_y + threadIdx.y;
    float sum = 0.0;

    for (int k=0; k<WIDTH; k++) {
        sum += A[y*WIDTH+k] * B[k*WIDTH+x];
    }

    C[y*WIDTH+x] = sum;
}

# %% [markdown]
# This kernel simply creates a single thread per output element. Each thread computes the index of the element it is responsible for, and iterates over the corresponding row in A, and corresponding column in B.

# %% [markdown]
# # Setup tuning parameters

# %% [markdown]
# Now we will explain how to use the kernel_tuner to tune all the parameters of this highly-flexible implementation. We'll first show the Python script and then explain it step-by-step.

# %%
#!/usr/bin/env python
import numpy
import kernel_tuner
from collections import OrderedDict

problem_size = (4096, 4096)
size = numpy.prod(problem_size)

A = numpy.random.randn(*problem_size).astype(numpy.float32)
B = numpy.random.randn(*problem_size).astype(numpy.float32)
C = numpy.zeros_like(A)

args = [C, A, B]

tune_params = OrderedDict()

tune_params["block_size_x"] = [2**i for i in range(3,7)]
tune_params["block_size_y"] = [2**i for i in range(6)]

answer = [numpy.dot(A,B), None, None]

# %% [markdown]
# As usual we first setup the kernel arguments and problem size so that the kernel_tuner knows how to call the kernel. Then for the block_size_x we choose a range of thread block sizes that seem reasonable, in this case [16, 32, 64]. You typically want the total number of threads within a thread block to be a multiple of 32 (warpsize) or even 64 (number of register banks on some cards). And because the tiling factors will increase the amount of work per thread block (see below), as well as the amount of shared memory used we start a tad conservatively here. For block_size_y, and the tiling factors in both directions, we just pick a range of powers of two.

# %%
results = kernel_tuner.tune_kernel("matmul_kernel", "matmul_naive.cu",
                                   problem_size, args, tune_params, answer=answer, atol=1e-3)
# Out:
# Using: GeForce GTX TITAN X
# block_size_x=8, block_size_y=1, time=3345.30566406
# block_size_x=8, block_size_y=2, time=1677.3567627
# block_size_x=8, block_size_y=4, time=888.376782227
# block_size_x=8, block_size_y=8, time=857.269091797
# block_size_x=8, block_size_y=16, time=782.440197754
# block_size_x=8, block_size_y=32, time=598.204455566
# block_size_x=16, block_size_y=1, time=1630.11213379
# block_size_x=16, block_size_y=2, time=821.787939453
# block_size_x=16, block_size_y=4, time=783.853503418
# block_size_x=16, block_size_y=8, time=710.253039551
# block_size_x=16, block_size_y=16, time=582.648266602
# block_size_x=16, block_size_y=32, time=497.817297363
# block_size_x=32, block_size_y=1, time=983.634216309
# block_size_x=32, block_size_y=2, time=845.382946777
# block_size_x=32, block_size_y=4, time=814.851721191
# block_size_x=32, block_size_y=8, time=620.501367188
# block_size_x=32, block_size_y=16, time=548.021582031
# block_size_x=32, block_size_y=32, time=515.425341797
# block_size_x=64, block_size_y=1, time=966.117370605
# block_size_x=64, block_size_y=2, time=955.493713379
# block_size_x=64, block_size_y=4, time=791.534191895
# block_size_x=64, block_size_y=8, time=679.577416992
# block_size_x=64, block_size_y=16, time=601.661181641
# best performing configuration: block_size_x=16, block_size_y=32, time=497.817297363

# %% [markdown]
# There aren't many parameters to tune yet, and more importantly, tuning will not be very effective because this kernel will be limited by bandwidth rather than compute.

# %% [markdown]
# The utilisation of the GPU is very low, even for the optimal combination of block_size_x and block_size_y:
#
# ![](Matmul-naive-utilisation.png)
#
# There is however, a lot of opportunity for data reuse, which is realized by making the threads in a thread block collaborate.

# %% [markdown]
# # Increase data reuse
#
# This can be solved by using a technique called loop-blocking or loop-tiling. We define two square data structures in shared memory, which will be used for storing square parts of matrix A and B. The threads in a thread block will collaboratively fill these two variables, and then proceed to perform all the computations that need this data, before moving to the next blocked iteration.

# %%
# %load matmul_data_reuse.cu
#define WIDTH 4096

__global__ void matmul_kernel(float *C, float *A, float *B) {

    __shared__ float sA[block_size_y][block_size_x];
    __shared__ float sB[block_size_y][block_size_x];

    int tx = threadIdx.x;
    int ty = threadIdx.y;
    int x = blockIdx.x * block_size_x + tx;
    int y = blockIdx.y * block_size_y + ty;

    float sum = 0.0;
    int k,kb;

    for (k=0; k<WIDTH; k+=block_size_x) {
        __synchthreads();
        sA[ty][tx] = A[y*WIDTH+k+tx];
        sB[ty][tx] = B[(k+ty)*WIDTH+x];
        __synchthreads();

        for (kb=0; kb<block_size_x; kb++) {
            sum += sA[ty][kb] * sB[kb][tx];
        }

    }

    C[y*WIDTH+x] = sum;
}

# %%
restrict = ["block_size_x==block_size_y"] 

results = kernel_tuner.tune_kernel("matmul_kernel", "matmul_data_reuse.cu",
                                   problem_size, args, tune_params, restrictions=restrict, answer=answer, atol=1e-3)
# Out:
# Using: GeForce GTX TITAN X
# block_size_x=8, block_size_y=8, time=247.659780884
# block_size_x=16, block_size_y=16, time=181.600396729
# block_size_x=32, block_size_y=32, time=178.936386108
# best performing configuration: block_size_x=32, block_size_y=32, time=178.936386108

# %% [markdown]
# This kernel drastically reduces memory bandwidth consumption. It is about three times faster now, which comes from much better memory use:
#
# ![](Matmul-utilisation-with-data-reuse.png)
#
# The compute intensity has dropped slightly, because of the syncthread operations.

# %% [markdown]
# However, there still is not too much that can be tuned in this kernel. In fact, because the thread block size needs to be a square, there only a handful of configurations we can try. Fortunately, we can add several more optimizations to the code that also open the parameter space for tuning.

# %% [markdown]
# # Increase work per thread

# %% [markdown]
# We will use two different forms of 1xN tiling in this example:
#
# First of all, in the x-direction we will use tiling in a way that is similar to the convolution example. The area of output data that is processed by a single thread block is increased by a factor of N, and as such shared memory usage also increases by a factor N. This means that the number of thread blocks needed to execute the kernel for this problem size is reduced by a factor of N, where N is the tiling factor. While this may reduce occupancy due to increased shared memory and register usage, this optimization drastically reduces the number of redundant instructions that were previously distributed across multiple thread blocks.
#
# Secondly, in the y-direction we will use a different form of 1xN tiling, where we tile within the thread block. This too means that threads will compute multiple elements, but in this case, not the total number of thread blocks is reduced, but instead the number of threads per block goes down.
#
# Note that these two different forms of tiling could have combined in different or even multiple ways to increase the tuning parameter space even further. However, for the purposes of this example, the resulting kernel is already complex enough:

# %%
# %load matmul_increase_work_per_thread.cu
#define WIDTH 4096

__global__ void matmul_kernel(float *C, float *A, float *B) {

    __shared__ float sA[block_size_y*tile_size_y][block_size_x];
    __shared__ float sB[block_size_y*tile_size_y][block_size_x * tile_size_x];

    int tx = threadIdx.x;
    int ty = threadIdx.y;
    int x = blockIdx.x * block_size_x * tile_size_x + threadIdx.x;
    int y = blockIdx.y * block_size_y * tile_size_y + threadIdx.y;
    int k, kb;

    float sum[tile_size_y][tile_size_x];

    for (k = 0; k < WIDTH; k += block_size_x) {

        __syncthreads ();
        #pragma unroll
        for (int i = 0; i < tile_size_y; i++) {
            sA[ty + block_size_y * i][tx] = A[y * WIDTH + block_size_y * i * WIDTH + k + tx];

            #pragma unroll
            for (int j = 0; j < tile_size_x; j++) {
                sB[ty + block_size_y * i][tx + j * block_size_x] = B[(k + ty + block_size_y * i) * WIDTH + x + j * block_size_x];
            }
        }
        __syncthreads ();

        //compute
        #pragma unroll
        for (kb = 0; kb < block_size_x; kb++) {

            #pragma unroll
            for (int i = 0; i < tile_size_y; i++) {
                #pragma unroll
                for (int j = 0; j < tile_size_x; j++) {
                        sum[i][j] += sA[ty + block_size_y * i][kb] * sB[kb][tx + j * block_size_x];
                    }
            }

        }

    }

    //store result
    #pragma unroll
    for (int i = 0; i < tile_size_y; i++) {
        #pragma unroll
        for (int j = 0; j < tile_size_x; j++) {
            C[y * WIDTH + x + block_size_y * i * WIDTH + j * block_size_x] = sum[i][j];
        }
    }

}

# %% [markdown]
# Remember that the area operated on by the thread block should be a square. In this kernel however, we allow block_size_x and block_size_y to vary independently, while tile_size_y increases the amount of work per thread in the y-direction within the thread block. This yields a discontinuous search space in which only part of the configurations are actually valid. Therefore we use the restrictions optional argument of tune_kernel.
#
# restrictions expects a list of strings that contain a boolean expression that may use the tuning parameters as variables. Any occurrences of tuning parameter names will be replaced with the specific value of this parameter when the kernel configuration is evaluated. All expressions in the list passed as restrictions need to evaluate to True for the configuration to be considered valid and therefore part of the parameter space.

# %%
tune_params["tile_size_x"] = [2**i for i in range(4)]
tune_params["tile_size_y"] = [2**i for i in range(4)]

grid_div_x = ["block_size_x", "tile_size_x"]
grid_div_y = ["block_size_y", "tile_size_y"]

restrict = ["block_size_x==block_size_y*tile_size_y"]

results = kernel_tuner.tune_kernel("matmul_kernel", "matmul_increase_work_per_thread.cu",
    problem_size, args, tune_params,
    grid_div_y=grid_div_y, grid_div_x=grid_div_x,
    restrictions=restrict, verbose=True)
# Out:
# Using: GeForce GTX TITAN X
# skipping config 8_1_1_1 reason: config fails restriction
# skipping config 8_1_1_2 reason: config fails restriction
# skipping config 8_1_1_4 reason: config fails restriction
# block_size_x=8, block_size_y=1, tile_size_x=1, tile_size_y=8, time=489.548773193
# skipping config 8_1_2_1 reason: config fails restriction
# skipping config 8_1_2_2 reason: config fails restriction
# skipping config 8_1_2_4 reason: config fails restriction
# block_size_x=8, block_size_y=1, tile_size_x=2, tile_size_y=8, time=302.98302002
# skipping config 8_1_4_1 reason: config fails restriction
# skipping config 8_1_4_2 reason: config fails restriction
# skipping config 8_1_4_4 reason: config fails restriction
# block_size_x=8, block_size_y=1, tile_size_x=4, tile_size_y=8, time=233.32043457
# skipping config 8_1_8_1 reason: config fails restriction
# skipping config 8_1_8_2 reason: config fails restriction
# skipping config 8_1_8_4 reason: config fails restriction
# block_size_x=8, block_size_y=1, tile_size_x=8, tile_size_y=8, time=185.396459961
# skipping config 8_2_1_1 reason: config fails restriction
# skipping config 8_2_1_2 reason: config fails restriction
# block_size_x=8, block_size_y=2, tile_size_x=1, tile_size_y=4, time=272.257427979
# skipping config 8_2_1_8 reason: config fails restriction
# skipping config 8_2_2_1 reason: config fails restriction
# skipping config 8_2_2_2 reason: config fails restriction
# block_size_x=8, block_size_y=2, tile_size_x=2, tile_size_y=4, time=183.444116211
# skipping config 8_2_2_8 reason: config fails restriction
# skipping config 8_2_4_1 reason: config fails restriction
# skipping config 8_2_4_2 reason: config fails restriction
# block_size_x=8, block_size_y=2, tile_size_x=4, tile_size_y=4, time=140.001809692
# skipping config 8_2_4_8 reason: config fails restriction
# skipping config 8_2_8_1 reason: config fails restriction
# skipping config 8_2_8_2 reason: config fails restriction
# block_size_x=8, block_size_y=2, tile_size_x=8, tile_size_y=4, time=131.143359375
# skipping config 8_2_8_8 reason: config fails restriction
# skipping config 8_4_1_1 reason: config fails restriction
# block_size_x=8, block_size_y=4, tile_size_x=1, tile_size_y=2, time=252.601382446
# skipping config 8_4_1_4 reason: config fails restriction
# skipping config 8_4_1_8 reason: config fails restriction
# skipping config 8_4_2_1 reason: config fails restriction
# block_size_x=8, block_size_y=4, tile_size_x=2, tile_size_y=2, time=147.362387085
# skipping config 8_4_2_4 reason: config fails restriction
# skipping config 8_4_2_8 reason: config fails restriction
# skipping config 8_4_4_1 reason: config fails restriction
# block_size_x=8, block_size_y=4, tile_size_x=4, tile_size_y=2, time=133.976135254
# skipping config 8_4_4_4 reason: config fails restriction
# skipping config 8_4_4_8 reason: config fails restriction
# skipping config 8_4_8_1 reason: config fails restriction
# block_size_x=8, block_size_y=4, tile_size_x=8, tile_size_y=2, time=118.534162903
# skipping config 8_4_8_4 reason: config fails restriction
# skipping config 8_4_8_8 reason: config fails restriction
# block_size_x=8, block_size_y=8, tile_size_x=1, tile_size_y=1, time=253.168048096
# skipping config 8_8_1_2 reason: config fails restriction
# skipping config 8_8_1_4 reason: config fails restriction
# skipping config 8_8_1_8 reason: config fails restriction
# block_size_x=8, block_size_y=8, tile_size_x=2, tile_size_y=1, time=167.922525024
# skipping config 8_8_2_2 reason: config fails restriction
# skipping config 8_8_2_4 reason: config fails restriction
# skipping config 8_8_2_8 reason: config fails restriction
# block_size_x=8, block_size_y=8, tile_size_x=4, tile_size_y=1, time=155.057357788
# skipping config 8_8_4_2 reason: config fails restriction
# skipping config 8_8_4_4 reason: config fails restriction
# skipping config 8_8_4_8 reason: config fails restriction
# block_size_x=8, block_size_y=8, tile_size_x=8, tile_size_y=1, time=139.894989014
# skipping config 8_8_8_2 reason: config fails restriction
# skipping config 8_8_8_4 reason: config fails restriction
# skipping config 8_8_8_8 reason: config fails restriction
# skipping config 8_16_1_1 reason: config fails restriction
# skipping config 8_16_1_2 reason: config fails restriction
# skipping config 8_16_1_4 reason: config fails restriction
# skipping config 8_16_1_8 reason: config fails restriction
# skipping config 8_16_2_1 reason: config fails restriction
# skipping config 8_16_2_2 reason: config fails restriction
# skipping config 8_16_2_4 reason: config fails restriction
# skipping config 8_16_2_8 reason: config fails restriction
# skipping config 8_16_4_1 reason: config fails restriction
# skipping config 8_16_4_2 reason: config fails restriction
# skipping config 8_16_4_4 reason: config fails restriction
# skipping config 8_16_4_8 reason: config fails restriction
# skipping config 8_16_8_1 reason: config fails restriction
# skipping config 8_16_8_2 reason: config fails restriction
# skipping config 8_16_8_4 reason: config fails restriction
# skipping config 8_16_8_8 reason: config fails restriction
# skipping config 8_32_1_1 reason: config fails restriction
# skipping config 8_32_1_2 reason: config fails restriction
# skipping config 8_32_1_4 reason: config fails restriction
# skipping config 8_32_1_8 reason: config fails restriction
# skipping config 8_32_2_1 reason: config fails restriction
# skipping config 8_32_2_2 reason: config fails restriction
# skipping config 8_32_2_4 reason: config fails restriction
# skipping config 8_32_2_8 reason: config fails restriction
# skipping config 8_32_4_1 reason: config fails restriction
# skipping config 8_32_4_2 reason: config fails restriction
# skipping config 8_32_4_4 reason: config fails restriction
# skipping config 8_32_4_8 reason: config fails restriction
# skipping config 8_32_8_1 reason: config fails restriction
# skipping config 8_32_8_2 reason: config fails restriction
# skipping config 8_32_8_4 reason: config fails restriction
# skipping config 8_32_8_8 reason: config fails restriction
# skipping config 16_1_1_1 reason: config fails restriction
# skipping config 16_1_1_2 reason: config fails restriction
# skipping config 16_1_1_4 reason: config fails restriction
# skipping config 16_1_1_8 reason: config fails restriction
# skipping config 16_1_2_1 reason: config fails restriction
# skipping config 16_1_2_2 reason: config fails restriction
# skipping config 16_1_2_4 reason: config fails restriction
# skipping config 16_1_2_8 reason: config fails restriction
# skipping config 16_1_4_1 reason: config fails restriction
# skipping config 16_1_4_2 reason: config fails restriction
# skipping config 16_1_4_4 reason: config fails restriction
# skipping config 16_1_4_8 reason: config fails restriction
# skipping config 16_1_8_1 reason: config fails restriction
# skipping config 16_1_8_2 reason: config fails restriction
# skipping config 16_1_8_4 reason: config fails restriction
# skipping config 16_1_8_8 reason: config fails restriction
# skipping config 16_2_1_1 reason: config fails restriction
# skipping config 16_2_1_2 reason: config fails restriction
# skipping config 16_2_1_4 reason: config fails restriction
# block_size_x=16, block_size_y=2, tile_size_x=1, tile_size_y=8, time=107.024531555
# skipping config 16_2_2_1 reason: config fails restriction
# skipping config 16_2_2_2 reason: config fails restriction
# skipping config 16_2_2_4 reason: config fails restriction
# block_size_x=16, block_size_y=2, tile_size_x=2, tile_size_y=8, time=74.6922058105
# skipping config 16_2_4_1 reason: config fails restriction
# skipping config 16_2_4_2 reason: config fails restriction
# skipping config 16_2_4_4 reason: config fails restriction
# block_size_x=16, block_size_y=2, tile_size_x=4, tile_size_y=8, time=62.9394752502
# skipping config 16_2_8_1 reason: config fails restriction
# skipping config 16_2_8_2 reason: config fails restriction
# skipping config 16_2_8_4 reason: config fails restriction
# block_size_x=16, block_size_y=2, tile_size_x=8, tile_size_y=8, time=67.2532363892
# skipping config 16_4_1_1 reason: config fails restriction
# skipping config 16_4_1_2 reason: config fails restriction
# block_size_x=16, block_size_y=4, tile_size_x=1, tile_size_y=4, time=117.279769897
# skipping config 16_4_1_8 reason: config fails restriction
# skipping config 16_4_2_1 reason: config fails restriction
# skipping config 16_4_2_2 reason: config fails restriction
# block_size_x=16, block_size_y=4, tile_size_x=2, tile_size_y=4, time=78.6080383301
# skipping config 16_4_2_8 reason: config fails restriction
# skipping config 16_4_4_1 reason: config fails restriction
# skipping config 16_4_4_2 reason: config fails restriction
# block_size_x=16, block_size_y=4, tile_size_x=4, tile_size_y=4, time=63.2790016174
# skipping config 16_4_4_8 reason: config fails restriction
# skipping config 16_4_8_1 reason: config fails restriction
# skipping config 16_4_8_2 reason: config fails restriction
# block_size_x=16, block_size_y=4, tile_size_x=8, tile_size_y=4, time=68.3843338013
# skipping config 16_4_8_8 reason: config fails restriction
# skipping config 16_8_1_1 reason: config fails restriction
# block_size_x=16, block_size_y=8, tile_size_x=1, tile_size_y=2, time=138.952127075
# skipping config 16_8_1_4 reason: config fails restriction
# skipping config 16_8_1_8 reason: config fails restriction
# skipping config 16_8_2_1 reason: config fails restriction
# block_size_x=16, block_size_y=8, tile_size_x=2, tile_size_y=2, time=98.6710464478
# skipping config 16_8_2_4 reason: config fails restriction
# skipping config 16_8_2_8 reason: config fails restriction
# skipping config 16_8_4_1 reason: config fails restriction
# block_size_x=16, block_size_y=8, tile_size_x=4, tile_size_y=2, time=77.4940933228
# skipping config 16_8_4_4 reason: config fails restriction
# skipping config 16_8_4_8 reason: config fails restriction
# skipping config 16_8_8_1 reason: config fails restriction
# block_size_x=16, block_size_y=8, tile_size_x=8, tile_size_y=2, time=76.0030975342
# skipping config 16_8_8_4 reason: config fails restriction
# skipping config 16_8_8_8 reason: config fails restriction
# block_size_x=16, block_size_y=16, tile_size_x=1, tile_size_y=1, time=179.829571533
# skipping config 16_16_1_2 reason: config fails restriction
# skipping config 16_16_1_4 reason: config fails restriction
# skipping config 16_16_1_8 reason: config fails restriction
# block_size_x=16, block_size_y=16, tile_size_x=2, tile_size_y=1, time=137.658905029
# skipping config 16_16_2_2 reason: config fails restriction
# skipping config 16_16_2_4 reason: config fails restriction
# skipping config 16_16_2_8 reason: config fails restriction
# block_size_x=16, block_size_y=16, tile_size_x=4, tile_size_y=1, time=114.375027466
# skipping config 16_16_4_2 reason: config fails restriction
# skipping config 16_16_4_4 reason: config fails restriction
# skipping config 16_16_4_8 reason: config fails restriction
# block_size_x=16, block_size_y=16, tile_size_x=8, tile_size_y=1, time=104.209580994
# skipping config 16_16_8_2 reason: config fails restriction
# skipping config 16_16_8_4 reason: config fails restriction
# skipping config 16_16_8_8 reason: config fails restriction
# skipping config 16_32_1_1 reason: config fails restriction
# skipping config 16_32_1_2 reason: config fails restriction
# skipping config 16_32_1_4 reason: config fails restriction
# skipping config 16_32_1_8 reason: config fails restriction
# skipping config 16_32_2_1 reason: config fails restriction
# skipping config 16_32_2_2 reason: config fails restriction
# skipping config 16_32_2_4 reason: config fails restriction
# skipping config 16_32_2_8 reason: config fails restriction
# skipping config 16_32_4_1 reason: config fails restriction
# skipping config 16_32_4_2 reason: config fails restriction
# skipping config 16_32_4_4 reason: config fails restriction
# skipping config 16_32_4_8 reason: config fails restriction
# skipping config 16_32_8_1 reason: config fails restriction
# skipping config 16_32_8_2 reason: config fails restriction
# skipping config 16_32_8_4 reason: config fails restriction
# skipping config 16_32_8_8 reason: config fails restriction
# skipping config 32_1_1_1 reason: config fails restriction
# skipping config 32_1_1_2 reason: config fails restriction
# skipping config 32_1_1_4 reason: config fails restriction
# skipping config 32_1_1_8 reason: config fails restriction
# skipping config 32_1_2_1 reason: config fails restriction
# skipping config 32_1_2_2 reason: config fails restriction
# skipping config 32_1_2_4 reason: config fails restriction
# skipping config 32_1_2_8 reason: config fails restriction
# skipping config 32_1_4_1 reason: config fails restriction
# skipping config 32_1_4_2 reason: config fails restriction
# skipping config 32_1_4_4 reason: config fails restriction
# skipping config 32_1_4_8 reason: config fails restriction
# skipping config 32_1_8_1 reason: config fails restriction
# skipping config 32_1_8_2 reason: config fails restriction
# skipping config 32_1_8_4 reason: config fails restriction
# skipping config 32_1_8_8 reason: config fails restriction
# skipping config 32_2_1_1 reason: config fails restriction
# skipping config 32_2_1_2 reason: config fails restriction
# skipping config 32_2_1_4 reason: config fails restriction
# skipping config 32_2_1_8 reason: config fails restriction
# skipping config 32_2_2_1 reason: config fails restriction
# skipping config 32_2_2_2 reason: config fails restriction
# skipping config 32_2_2_4 reason: config fails restriction
# skipping config 32_2_2_8 reason: config fails restriction
# skipping config 32_2_4_1 reason: config fails restriction
# skipping config 32_2_4_2 reason: config fails restriction
# skipping config 32_2_4_4 reason: config fails restriction
# skipping config 32_2_4_8 reason: config fails restriction
# skipping config 32_2_8_1 reason: config fails restriction
# skipping config 32_2_8_2 reason: config fails restriction
# skipping config 32_2_8_4 reason: config fails restriction
# skipping config 32_2_8_8 reason: config fails restriction
# skipping config 32_4_1_1 reason: config fails restriction
# skipping config 32_4_1_2 reason: config fails restriction
# skipping config 32_4_1_4 reason: config fails restriction
# block_size_x=32, block_size_y=4, tile_size_x=1, tile_size_y=8, time=95.4988723755
# skipping config 32_4_2_1 reason: config fails restriction
# skipping config 32_4_2_2 reason: config fails restriction
# skipping config 32_4_2_4 reason: config fails restriction
# block_size_x=32, block_size_y=4, tile_size_x=2, tile_size_y=8, time=57.0261306763
# skipping config 32_4_4_1 reason: config fails restriction
# skipping config 32_4_4_2 reason: config fails restriction
# skipping config 32_4_4_4 reason: config fails restriction
# block_size_x=32, block_size_y=4, tile_size_x=4, tile_size_y=8, time=42.706098938
# skipping config 32_4_8_1 reason: config fails restriction
# skipping config 32_4_8_2 reason: config fails restriction
# skipping config 32_4_8_4 reason: config fails restriction
# block_size_x=32, block_size_y=4, tile_size_x=8, tile_size_y=8, time=54.2833274841
# skipping config 32_8_1_1 reason: config fails restriction
# skipping config 32_8_1_2 reason: config fails restriction
# block_size_x=32, block_size_y=8, tile_size_x=1, tile_size_y=4, time=104.696820068
# skipping config 32_8_1_8 reason: config fails restriction
# skipping config 32_8_2_1 reason: config fails restriction
# skipping config 32_8_2_2 reason: config fails restriction
# block_size_x=32, block_size_y=8, tile_size_x=2, tile_size_y=4, time=66.2101699829
# skipping config 32_8_2_8 reason: config fails restriction
# skipping config 32_8_4_1 reason: config fails restriction
# skipping config 32_8_4_2 reason: config fails restriction
# block_size_x=32, block_size_y=8, tile_size_x=4, tile_size_y=4, time=47.2293769836
# skipping config 32_8_4_8 reason: config fails restriction
# skipping config 32_8_8_1 reason: config fails restriction
# skipping config 32_8_8_2 reason: config fails restriction
# block_size_x=32, block_size_y=8, tile_size_x=8, tile_size_y=4, time=50.5929092407
# skipping config 32_8_8_8 reason: config fails restriction
# skipping config 32_16_1_1 reason: config fails restriction
# block_size_x=32, block_size_y=16, tile_size_x=1, tile_size_y=2, time=126.456729126
# skipping config 32_16_1_4 reason: config fails restriction
# skipping config 32_16_1_8 reason: config fails restriction
# skipping config 32_16_2_1 reason: config fails restriction
# block_size_x=32, block_size_y=16, tile_size_x=2, tile_size_y=2, time=86.7228363037
# skipping config 32_16_2_4 reason: config fails restriction
# skipping config 32_16_2_8 reason: config fails restriction
# skipping config 32_16_4_1 reason: config fails restriction
# block_size_x=32, block_size_y=16, tile_size_x=4, tile_size_y=2, time=67.2661819458
# skipping config 32_16_4_4 reason: config fails restriction
# skipping config 32_16_4_8 reason: config fails restriction
# skipping config 32_16_8_1 reason: config fails restriction
# block_size_x=32, block_size_y=16, tile_size_x=8, tile_size_y=2, time=58.1954170227
# skipping config 32_16_8_4 reason: config fails restriction
# skipping config 32_16_8_8 reason: config fails restriction
# block_size_x=32, block_size_y=32, tile_size_x=1, tile_size_y=1, time=180.236724854
# skipping config 32_32_1_2 reason: config fails restriction
# skipping config 32_32_1_4 reason: config fails restriction
# skipping config 32_32_1_8 reason: config fails restriction
# block_size_x=32, block_size_y=32, tile_size_x=2, tile_size_y=1, time=133.088796997
# skipping config 32_32_2_2 reason: config fails restriction
# skipping config 32_32_2_4 reason: config fails restriction
# skipping config 32_32_2_8 reason: config fails restriction
# block_size_x=32, block_size_y=32, tile_size_x=4, tile_size_y=1, time=109.664057922
# skipping config 32_32_4_2 reason: config fails restriction
# skipping config 32_32_4_4 reason: config fails restriction
# skipping config 32_32_4_8 reason: config fails restriction
# block_size_x=32, block_size_y=32, tile_size_x=8, tile_size_y=1, time=97.5094070435
# skipping config 32_32_8_2 reason: config fails restriction
# skipping config 32_32_8_4 reason: config fails restriction
# skipping config 32_32_8_8 reason: config fails restriction
# skipping config 64_1_1_1 reason: config fails restriction
# skipping config 64_1_1_2 reason: config fails restriction
# skipping config 64_1_1_4 reason: config fails restriction
# skipping config 64_1_1_8 reason: config fails restriction
# skipping config 64_1_2_1 reason: config fails restriction
# skipping config 64_1_2_2 reason: config fails restriction
# skipping config 64_1_2_4 reason: config fails restriction
# skipping config 64_1_2_8 reason: config fails restriction
# skipping config 64_1_4_1 reason: config fails restriction
# skipping config 64_1_4_2 reason: config fails restriction
# skipping config 64_1_4_4 reason: config fails restriction
# skipping config 64_1_4_8 reason: config fails restriction
# skipping config 64_1_8_1 reason: config fails restriction
# skipping config 64_1_8_2 reason: config fails restriction
# skipping config 64_1_8_4 reason: config fails restriction
# skipping config 64_1_8_8 reason: config fails restriction
# skipping config 64_2_1_1 reason: config fails restriction
# skipping config 64_2_1_2 reason: config fails restriction
# skipping config 64_2_1_4 reason: config fails restriction
# skipping config 64_2_1_8 reason: config fails restriction
# skipping config 64_2_2_1 reason: config fails restriction
# skipping config 64_2_2_2 reason: config fails restriction
# skipping config 64_2_2_4 reason: config fails restriction
# skipping config 64_2_2_8 reason: config fails restriction
# skipping config 64_2_4_1 reason: config fails restriction
# skipping config 64_2_4_2 reason: config fails restriction
# skipping config 64_2_4_4 reason: config fails restriction
# skipping config 64_2_4_8 reason: config fails restriction
# skipping config 64_2_8_1 reason: config fails restriction
# skipping config 64_2_8_2 reason: config fails restriction
# skipping config 64_2_8_4 reason: config fails restriction
# skipping config 64_2_8_8 reason: config fails restriction
# skipping config 64_4_1_1 reason: config fails restriction
# skipping config 64_4_1_2 reason: config fails restriction
# skipping config 64_4_1_4 reason: config fails restriction
# skipping config 64_4_1_8 reason: config fails restriction
# skipping config 64_4_2_1 reason: config fails restriction
# skipping config 64_4_2_2 reason: config fails restriction
# skipping config 64_4_2_4 reason: config fails restriction
# skipping config 64_4_2_8 reason: config fails restriction
# skipping config 64_4_4_1 reason: config fails restriction
# skipping config 64_4_4_2 reason: config fails restriction
# skipping config 64_4_4_4 reason: config fails restriction
# skipping config 64_4_4_8 reason: config fails restriction
# skipping config 64_4_8_1 reason: config fails restriction
# skipping config 64_4_8_2 reason: config fails restriction
# skipping config 64_4_8_4 reason: config fails restriction
# skipping config 64_4_8_8 reason: config fails restriction
# skipping config 64_8_1_1 reason: config fails restriction
# skipping config 64_8_1_2 reason: config fails restriction
# skipping config 64_8_1_4 reason: config fails restriction
# block_size_x=64, block_size_y=8, tile_size_x=1, tile_size_y=8, time=92.9658477783
# skipping config 64_8_2_1 reason: config fails restriction
# skipping config 64_8_2_2 reason: config fails restriction
# skipping config 64_8_2_4 reason: config fails restriction
# block_size_x=64, block_size_y=8, tile_size_x=2, tile_size_y=8, time=56.1415870667
# skipping config 64_8_4_1 reason: config fails restriction
# skipping config 64_8_4_2 reason: config fails restriction
# skipping config 64_8_4_4 reason: config fails restriction
# skipping config matmul_kernel_64_8_4_8 reason: too much shared memory used
# skipping config 64_8_8_1 reason: config fails restriction
# skipping config 64_8_8_2 reason: config fails restriction
# skipping config 64_8_8_4 reason: config fails restriction
# skipping config matmul_kernel_64_8_8_8 reason: too much shared memory used
# skipping config 64_16_1_1 reason: config fails restriction
# skipping config 64_16_1_2 reason: config fails restriction
# block_size_x=64, block_size_y=16, tile_size_x=1, tile_size_y=4, time=107.298657227
# skipping config 64_16_1_8 reason: config fails restriction
# skipping config 64_16_2_1 reason: config fails restriction
# skipping config 64_16_2_2 reason: config fails restriction
# block_size_x=64, block_size_y=16, tile_size_x=2, tile_size_y=4, time=65.0967300415
# skipping config 64_16_2_8 reason: config fails restriction
# skipping config 64_16_4_1 reason: config fails restriction
# skipping config 64_16_4_2 reason: config fails restriction
# skipping config matmul_kernel_64_16_4_4 reason: too much shared memory used
# skipping config 64_16_4_8 reason: config fails restriction
# skipping config 64_16_8_1 reason: config fails restriction
# skipping config 64_16_8_2 reason: config fails restriction
# skipping config matmul_kernel_64_16_8_4 reason: too much shared memory used
# skipping config 64_16_8_8 reason: config fails restriction
# skipping config 64_32_1_1 reason: config fails restriction
# skipping config 64_32_1_2 reason: too many threads per block
# skipping config 64_32_1_4 reason: config fails restriction
# skipping config 64_32_1_8 reason: config fails restriction
# skipping config 64_32_2_1 reason: config fails restriction
# skipping config 64_32_2_2 reason: too many threads per block
# skipping config 64_32_2_4 reason: config fails restriction
# skipping config 64_32_2_8 reason: config fails restriction
# skipping config 64_32_4_1 reason: config fails restriction
# skipping config 64_32_4_2 reason: too many threads per block
# skipping config 64_32_4_4 reason: config fails restriction
# skipping config 64_32_4_8 reason: config fails restriction
# skipping config 64_32_8_1 reason: config fails restriction
# skipping config 64_32_8_2 reason: too many threads per block
# skipping config 64_32_8_4 reason: config fails restriction
# skipping config 64_32_8_8 reason: config fails restriction
# best performing configuration: block_size_x=32, block_size_y=4, tile_size_x=4, tile_size_y=8, time=42.706098938

# %%
params = {"block_size_x": 32, "block_size_y": 4, "tile_size_x": 4, "tile_size_y":8}

# %%
results = kernel_tuner.run_kernel("matmul_kernel", "matmul_increase_work_per_thread.cu", problem_size, args, params)
# Out:
# Using: GeForce GTX TITAN X
# ---------------------------------------------------------------------------
# LogicError                                Traceback (most recent call last)
# <ipython-input-14-2778d7e36d8d> in <module>()
# ----> 1 results = kernel_tuner.run_kernel("matmul_kernel", "matmul_increase_work_per_thread.cu", problem_size, args, params)
#
# /home/hspreeuw/anaconda3/lib/python3.5/site-packages/kernel_tuner/interface.py in run_kernel(kernel_name, kernel_string, problem_size, arguments, params, grid_div_x, grid_div_y, grid_div_z, lang, device, platform, cmem_args, compiler, compiler_options, block_size_names, quiet)
#     457         else:
#     458             results.append(numpy.zeros_like(arg))
# --> 459             dev.memcpy_dtoh(results[-1], gpu_args[i])
#     460
#     461     return results
#
# /home/hspreeuw/anaconda3/lib/python3.5/site-packages/kernel_tuner/core.py in memcpy_dtoh(self, dest, src)
#     249     def memcpy_dtoh(self, dest, src):
#     250         """perform a device to host memory copy"""
# --> 251         self.dev.memcpy_dtoh(dest, src)
#     252
#     253     def ready_argument_list(self, arguments):
#
# /home/hspreeuw/anaconda3/lib/python3.5/site-packages/kernel_tuner/cuda.py in memcpy_dtoh(self, dest, src)
#     237         """
#     238         if isinstance(src, drv.DeviceAllocation):
# --> 239             drv.memcpy_dtoh(dest, src)
#     240         else:
#     241             dest = src
#
# LogicError: cuMemcpyDtoH failed: an illegal memory access was encountered

# %%
results = kernel_tuner.tune_kernel("matmul_kernel", "matmul_increase_work_per_thread.cu",
    problem_size, args, tune_params,
    grid_div_y=grid_div_y, grid_div_x=grid_div_x,
    restrictions=restrict, verbose=True)
# Out:
# Using: GeForce GTX TITAN X
# skipping config 8_1_1_1 reason: config fails restriction
# skipping config 8_1_1_2 reason: config fails restriction
# skipping config 8_1_1_4 reason: config fails restriction
# block_size_x=8, block_size_y=1, tile_size_x=1, tile_size_y=8, time=489.201403809
# skipping config 8_1_2_1 reason: config fails restriction
# skipping config 8_1_2_2 reason: config fails restriction
# skipping config 8_1_2_4 reason: config fails restriction
# block_size_x=8, block_size_y=1, tile_size_x=2, tile_size_y=8, time=300.227099609
# skipping config 8_1_4_1 reason: config fails restriction
# skipping config 8_1_4_2 reason: config fails restriction
# skipping config 8_1_4_4 reason: config fails restriction
# block_size_x=8, block_size_y=1, tile_size_x=4, tile_size_y=8, time=233.216320801
# skipping config 8_1_8_1 reason: config fails restriction
# skipping config 8_1_8_2 reason: config fails restriction
# skipping config 8_1_8_4 reason: config fails restriction
# block_size_x=8, block_size_y=1, tile_size_x=8, tile_size_y=8, time=184.688409424
# skipping config 8_2_1_1 reason: config fails restriction
# skipping config 8_2_1_2 reason: config fails restriction
# block_size_x=8, block_size_y=2, tile_size_x=1, tile_size_y=4, time=272.134204102
# skipping config 8_2_1_8 reason: config fails restriction
# skipping config 8_2_2_1 reason: config fails restriction
# skipping config 8_2_2_2 reason: config fails restriction
# block_size_x=8, block_size_y=2, tile_size_x=2, tile_size_y=4, time=182.71355896
# skipping config 8_2_2_8 reason: config fails restriction
# skipping config 8_2_4_1 reason: config fails restriction
# skipping config 8_2_4_2 reason: config fails restriction
# block_size_x=8, block_size_y=2, tile_size_x=4, tile_size_y=4, time=139.588635254
# skipping config 8_2_4_8 reason: config fails restriction
# skipping config 8_2_8_1 reason: config fails restriction
# skipping config 8_2_8_2 reason: config fails restriction
# block_size_x=8, block_size_y=2, tile_size_x=8, tile_size_y=4, time=130.487863159
# skipping config 8_2_8_8 reason: config fails restriction
# skipping config 8_4_1_1 reason: config fails restriction
# block_size_x=8, block_size_y=4, tile_size_x=1, tile_size_y=2, time=252.515420532
# skipping config 8_4_1_4 reason: config fails restriction
# skipping config 8_4_1_8 reason: config fails restriction
# skipping config 8_4_2_1 reason: config fails restriction
# block_size_x=8, block_size_y=4, tile_size_x=2, tile_size_y=2, time=146.270523071
# skipping config 8_4_2_4 reason: config fails restriction
# skipping config 8_4_2_8 reason: config fails restriction
# skipping config 8_4_4_1 reason: config fails restriction
# block_size_x=8, block_size_y=4, tile_size_x=4, tile_size_y=2, time=134.123239136
# skipping config 8_4_4_4 reason: config fails restriction
# skipping config 8_4_4_8 reason: config fails restriction
# skipping config 8_4_8_1 reason: config fails restriction
# block_size_x=8, block_size_y=4, tile_size_x=8, tile_size_y=2, time=115.609451294
# skipping config 8_4_8_4 reason: config fails restriction
# skipping config 8_4_8_8 reason: config fails restriction
# block_size_x=8, block_size_y=8, tile_size_x=1, tile_size_y=1, time=252.758248901
# skipping config 8_8_1_2 reason: config fails restriction
# skipping config 8_8_1_4 reason: config fails restriction
# skipping config 8_8_1_8 reason: config fails restriction
# block_size_x=8, block_size_y=8, tile_size_x=2, tile_size_y=1, time=167.244204712
# skipping config 8_8_2_2 reason: config fails restriction
# skipping config 8_8_2_4 reason: config fails restriction
# skipping config 8_8_2_8 reason: config fails restriction
# block_size_x=8, block_size_y=8, tile_size_x=4, tile_size_y=1, time=154.550469971
# skipping config 8_8_4_2 reason: config fails restriction
# skipping config 8_8_4_4 reason: config fails restriction
# skipping config 8_8_4_8 reason: config fails restriction
# block_size_x=8, block_size_y=8, tile_size_x=8, tile_size_y=1, time=139.954638672
# skipping config 8_8_8_2 reason: config fails restriction
# skipping config 8_8_8_4 reason: config fails restriction
# skipping config 8_8_8_8 reason: config fails restriction
# skipping config 8_16_1_1 reason: config fails restriction
# skipping config 8_16_1_2 reason: config fails restriction
# skipping config 8_16_1_4 reason: config fails restriction
# skipping config 8_16_1_8 reason: config fails restriction
# skipping config 8_16_2_1 reason: config fails restriction
# skipping config 8_16_2_2 reason: config fails restriction
# skipping config 8_16_2_4 reason: config fails restriction
# skipping config 8_16_2_8 reason: config fails restriction
# skipping config 8_16_4_1 reason: config fails restriction
# skipping config 8_16_4_2 reason: config fails restriction
# skipping config 8_16_4_4 reason: config fails restriction
# skipping config 8_16_4_8 reason: config fails restriction
# skipping config 8_16_8_1 reason: config fails restriction
# skipping config 8_16_8_2 reason: config fails restriction
# skipping config 8_16_8_4 reason: config fails restriction
# skipping config 8_16_8_8 reason: config fails restriction
# skipping config 8_32_1_1 reason: config fails restriction
# skipping config 8_32_1_2 reason: config fails restriction
# skipping config 8_32_1_4 reason: config fails restriction
# skipping config 8_32_1_8 reason: config fails restriction
# skipping config 8_32_2_1 reason: config fails restriction
# skipping config 8_32_2_2 reason: config fails restriction
# skipping config 8_32_2_4 reason: config fails restriction
# skipping config 8_32_2_8 reason: config fails restriction
# skipping config 8_32_4_1 reason: config fails restriction
# skipping config 8_32_4_2 reason: config fails restriction
# skipping config 8_32_4_4 reason: config fails restriction
# skipping config 8_32_4_8 reason: config fails restriction
# skipping config 8_32_8_1 reason: config fails restriction
# skipping config 8_32_8_2 reason: config fails restriction
# skipping config 8_32_8_4 reason: config fails restriction
# skipping config 8_32_8_8 reason: config fails restriction
# skipping config 16_1_1_1 reason: config fails restriction
# skipping config 16_1_1_2 reason: config fails restriction
# skipping config 16_1_1_4 reason: config fails restriction
# skipping config 16_1_1_8 reason: config fails restriction
# skipping config 16_1_2_1 reason: config fails restriction
# skipping config 16_1_2_2 reason: config fails restriction
# skipping config 16_1_2_4 reason: config fails restriction
# skipping config 16_1_2_8 reason: config fails restriction
# skipping config 16_1_4_1 reason: config fails restriction
# skipping config 16_1_4_2 reason: config fails restriction
# skipping config 16_1_4_4 reason: config fails restriction
# skipping config 16_1_4_8 reason: config fails restriction
# skipping config 16_1_8_1 reason: config fails restriction
# skipping config 16_1_8_2 reason: config fails restriction
# skipping config 16_1_8_4 reason: config fails restriction
# skipping config 16_1_8_8 reason: config fails restriction
# skipping config 16_2_1_1 reason: config fails restriction
# skipping config 16_2_1_2 reason: config fails restriction
# skipping config 16_2_1_4 reason: config fails restriction
# block_size_x=16, block_size_y=2, tile_size_x=1, tile_size_y=8, time=106.403495789
# skipping config 16_2_2_1 reason: config fails restriction
# skipping config 16_2_2_2 reason: config fails restriction
# skipping config 16_2_2_4 reason: config fails restriction
# block_size_x=16, block_size_y=2, tile_size_x=2, tile_size_y=8, time=74.0069488525
# skipping config 16_2_4_1 reason: config fails restriction
# skipping config 16_2_4_2 reason: config fails restriction
# skipping config 16_2_4_4 reason: config fails restriction
# block_size_x=16, block_size_y=2, tile_size_x=4, tile_size_y=8, time=62.6045379639
# skipping config 16_2_8_1 reason: config fails restriction
# skipping config 16_2_8_2 reason: config fails restriction
# skipping config 16_2_8_4 reason: config fails restriction
# block_size_x=16, block_size_y=2, tile_size_x=8, tile_size_y=8, time=67.0173828125
# skipping config 16_4_1_1 reason: config fails restriction
# skipping config 16_4_1_2 reason: config fails restriction
# block_size_x=16, block_size_y=4, tile_size_x=1, tile_size_y=4, time=116.792121887
# skipping config 16_4_1_8 reason: config fails restriction
# skipping config 16_4_2_1 reason: config fails restriction
# skipping config 16_4_2_2 reason: config fails restriction
# block_size_x=16, block_size_y=4, tile_size_x=2, tile_size_y=4, time=78.3085113525
# skipping config 16_4_2_8 reason: config fails restriction
# skipping config 16_4_4_1 reason: config fails restriction
# skipping config 16_4_4_2 reason: config fails restriction
# block_size_x=16, block_size_y=4, tile_size_x=4, tile_size_y=4, time=63.3342140198
# skipping config 16_4_4_8 reason: config fails restriction
# skipping config 16_4_8_1 reason: config fails restriction
# skipping config 16_4_8_2 reason: config fails restriction
# block_size_x=16, block_size_y=4, tile_size_x=8, tile_size_y=4, time=67.2011901855
# skipping config 16_4_8_8 reason: config fails restriction
# skipping config 16_8_1_1 reason: config fails restriction
# block_size_x=16, block_size_y=8, tile_size_x=1, tile_size_y=2, time=137.641113281
# skipping config 16_8_1_4 reason: config fails restriction
# skipping config 16_8_1_8 reason: config fails restriction
# skipping config 16_8_2_1 reason: config fails restriction
# block_size_x=16, block_size_y=8, tile_size_x=2, tile_size_y=2, time=98.587059021
# skipping config 16_8_2_4 reason: config fails restriction
# skipping config 16_8_2_8 reason: config fails restriction
# skipping config 16_8_4_1 reason: config fails restriction
# block_size_x=16, block_size_y=8, tile_size_x=4, tile_size_y=2, time=76.653112793
# skipping config 16_8_4_4 reason: config fails restriction
# skipping config 16_8_4_8 reason: config fails restriction
# skipping config 16_8_8_1 reason: config fails restriction
# block_size_x=16, block_size_y=8, tile_size_x=8, tile_size_y=2, time=75.437336731
# skipping config 16_8_8_4 reason: config fails restriction
# skipping config 16_8_8_8 reason: config fails restriction
# block_size_x=16, block_size_y=16, tile_size_x=1, tile_size_y=1, time=179.487347412
# skipping config 16_16_1_2 reason: config fails restriction
# skipping config 16_16_1_4 reason: config fails restriction
# skipping config 16_16_1_8 reason: config fails restriction
# block_size_x=16, block_size_y=16, tile_size_x=2, tile_size_y=1, time=137.268432617
# skipping config 16_16_2_2 reason: config fails restriction
# skipping config 16_16_2_4 reason: config fails restriction
# skipping config 16_16_2_8 reason: config fails restriction
# block_size_x=16, block_size_y=16, tile_size_x=4, tile_size_y=1, time=114.509240723
# skipping config 16_16_4_2 reason: config fails restriction
# skipping config 16_16_4_4 reason: config fails restriction
# skipping config 16_16_4_8 reason: config fails restriction
# block_size_x=16, block_size_y=16, tile_size_x=8, tile_size_y=1, time=103.026609802
# skipping config 16_16_8_2 reason: config fails restriction
# skipping config 16_16_8_4 reason: config fails restriction
# skipping config 16_16_8_8 reason: config fails restriction
# skipping config 16_32_1_1 reason: config fails restriction
# skipping config 16_32_1_2 reason: config fails restriction
# skipping config 16_32_1_4 reason: config fails restriction
# skipping config 16_32_1_8 reason: config fails restriction
# skipping config 16_32_2_1 reason: config fails restriction
# skipping config 16_32_2_2 reason: config fails restriction
# skipping config 16_32_2_4 reason: config fails restriction
# skipping config 16_32_2_8 reason: config fails restriction
# skipping config 16_32_4_1 reason: config fails restriction
# skipping config 16_32_4_2 reason: config fails restriction
# skipping config 16_32_4_4 reason: config fails restriction
# skipping config 16_32_4_8 reason: config fails restriction
# skipping config 16_32_8_1 reason: config fails restriction
# skipping config 16_32_8_2 reason: config fails restriction
# skipping config 16_32_8_4 reason: config fails restriction
# skipping config 16_32_8_8 reason: config fails restriction
# skipping config 32_1_1_1 reason: config fails restriction
# skipping config 32_1_1_2 reason: config fails restriction
# skipping config 32_1_1_4 reason: config fails restriction
# skipping config 32_1_1_8 reason: config fails restriction
# skipping config 32_1_2_1 reason: config fails restriction
# skipping config 32_1_2_2 reason: config fails restriction
# skipping config 32_1_2_4 reason: config fails restriction
# skipping config 32_1_2_8 reason: config fails restriction
# skipping config 32_1_4_1 reason: config fails restriction
# skipping config 32_1_4_2 reason: config fails restriction
# skipping config 32_1_4_4 reason: config fails restriction
# skipping config 32_1_4_8 reason: config fails restriction
# skipping config 32_1_8_1 reason: config fails restriction
# skipping config 32_1_8_2 reason: config fails restriction
# skipping config 32_1_8_4 reason: config fails restriction
# skipping config 32_1_8_8 reason: config fails restriction
# skipping config 32_2_1_1 reason: config fails restriction
# skipping config 32_2_1_2 reason: config fails restriction
# skipping config 32_2_1_4 reason: config fails restriction
# skipping config 32_2_1_8 reason: config fails restriction
# skipping config 32_2_2_1 reason: config fails restriction
# skipping config 32_2_2_2 reason: config fails restriction
# skipping config 32_2_2_4 reason: config fails restriction
# skipping config 32_2_2_8 reason: config fails restriction
# skipping config 32_2_4_1 reason: config fails restriction
# skipping config 32_2_4_2 reason: config fails restriction
# skipping config 32_2_4_4 reason: config fails restriction
# skipping config 32_2_4_8 reason: config fails restriction
# skipping config 32_2_8_1 reason: config fails restriction
# skipping config 32_2_8_2 reason: config fails restriction
# skipping config 32_2_8_4 reason: config fails restriction
# skipping config 32_2_8_8 reason: config fails restriction
# skipping config 32_4_1_1 reason: config fails restriction
# skipping config 32_4_1_2 reason: config fails restriction
# skipping config 32_4_1_4 reason: config fails restriction
# block_size_x=32, block_size_y=4, tile_size_x=1, tile_size_y=8, time=95.1243392944
# skipping config 32_4_2_1 reason: config fails restriction
# skipping config 32_4_2_2 reason: config fails restriction
# skipping config 32_4_2_4 reason: config fails restriction
# block_size_x=32, block_size_y=4, tile_size_x=2, tile_size_y=8, time=56.494316864
# skipping config 32_4_4_1 reason: config fails restriction
# skipping config 32_4_4_2 reason: config fails restriction
# skipping config 32_4_4_4 reason: config fails restriction
# block_size_x=32, block_size_y=4, tile_size_x=4, tile_size_y=8, time=43.9385276794
# skipping config 32_4_8_1 reason: config fails restriction
# skipping config 32_4_8_2 reason: config fails restriction
# skipping config 32_4_8_4 reason: config fails restriction
# block_size_x=32, block_size_y=4, tile_size_x=8, tile_size_y=8, time=52.0649337769
# skipping config 32_8_1_1 reason: config fails restriction
# skipping config 32_8_1_2 reason: config fails restriction
# block_size_x=32, block_size_y=8, tile_size_x=1, tile_size_y=4, time=104.42852478
# skipping config 32_8_1_8 reason: config fails restriction
# skipping config 32_8_2_1 reason: config fails restriction
# skipping config 32_8_2_2 reason: config fails restriction
# block_size_x=32, block_size_y=8, tile_size_x=2, tile_size_y=4, time=65.8633270264
# skipping config 32_8_2_8 reason: config fails restriction
# skipping config 32_8_4_1 reason: config fails restriction
# skipping config 32_8_4_2 reason: config fails restriction
# block_size_x=32, block_size_y=8, tile_size_x=4, tile_size_y=4, time=48.0604988098
# skipping config 32_8_4_8 reason: config fails restriction
# skipping config 32_8_8_1 reason: config fails restriction
# skipping config 32_8_8_2 reason: config fails restriction
# block_size_x=32, block_size_y=8, tile_size_x=8, tile_size_y=4, time=49.0645065308
# skipping config 32_8_8_8 reason: config fails restriction
# skipping config 32_16_1_1 reason: config fails restriction
# block_size_x=32, block_size_y=16, tile_size_x=1, tile_size_y=2, time=126.013381958
# skipping config 32_16_1_4 reason: config fails restriction
# skipping config 32_16_1_8 reason: config fails restriction
# skipping config 32_16_2_1 reason: config fails restriction
# block_size_x=32, block_size_y=16, tile_size_x=2, tile_size_y=2, time=86.6336639404
# skipping config 32_16_2_4 reason: config fails restriction
# skipping config 32_16_2_8 reason: config fails restriction
# skipping config 32_16_4_1 reason: config fails restriction
# block_size_x=32, block_size_y=16, tile_size_x=4, tile_size_y=2, time=66.6541625977
# skipping config 32_16_4_4 reason: config fails restriction
# skipping config 32_16_4_8 reason: config fails restriction
# skipping config 32_16_8_1 reason: config fails restriction
# block_size_x=32, block_size_y=16, tile_size_x=8, tile_size_y=2, time=58.6794364929
# skipping config 32_16_8_4 reason: config fails restriction
# skipping config 32_16_8_8 reason: config fails restriction
# block_size_x=32, block_size_y=32, tile_size_x=1, tile_size_y=1, time=177.711386108
# skipping config 32_32_1_2 reason: config fails restriction
# skipping config 32_32_1_4 reason: config fails restriction
# skipping config 32_32_1_8 reason: config fails restriction
# block_size_x=32, block_size_y=32, tile_size_x=2, tile_size_y=1, time=131.994311523
# skipping config 32_32_2_2 reason: config fails restriction
# skipping config 32_32_2_4 reason: config fails restriction
# skipping config 32_32_2_8 reason: config fails restriction
# block_size_x=32, block_size_y=32, tile_size_x=4, tile_size_y=1, time=108.450756836
# skipping config 32_32_4_2 reason: config fails restriction
# skipping config 32_32_4_4 reason: config fails restriction
# skipping config 32_32_4_8 reason: config fails restriction
# block_size_x=32, block_size_y=32, tile_size_x=8, tile_size_y=1, time=96.3248764038
# skipping config 32_32_8_2 reason: config fails restriction
# skipping config 32_32_8_4 reason: config fails restriction
# skipping config 32_32_8_8 reason: config fails restriction
# skipping config 64_1_1_1 reason: config fails restriction
# skipping config 64_1_1_2 reason: config fails restriction
# skipping config 64_1_1_4 reason: config fails restriction
# skipping config 64_1_1_8 reason: config fails restriction
# skipping config 64_1_2_1 reason: config fails restriction
# skipping config 64_1_2_2 reason: config fails restriction
# skipping config 64_1_2_4 reason: config fails restriction
# skipping config 64_1_2_8 reason: config fails restriction
# skipping config 64_1_4_1 reason: config fails restriction
# skipping config 64_1_4_2 reason: config fails restriction
# skipping config 64_1_4_4 reason: config fails restriction
# skipping config 64_1_4_8 reason: config fails restriction
# skipping config 64_1_8_1 reason: config fails restriction
# skipping config 64_1_8_2 reason: config fails restriction
# skipping config 64_1_8_4 reason: config fails restriction
# skipping config 64_1_8_8 reason: config fails restriction
# skipping config 64_2_1_1 reason: config fails restriction
# skipping config 64_2_1_2 reason: config fails restriction
# skipping config 64_2_1_4 reason: config fails restriction
# skipping config 64_2_1_8 reason: config fails restriction
# skipping config 64_2_2_1 reason: config fails restriction
# skipping config 64_2_2_2 reason: config fails restriction
# skipping config 64_2_2_4 reason: config fails restriction
# skipping config 64_2_2_8 reason: config fails restriction
# skipping config 64_2_4_1 reason: config fails restriction
# skipping config 64_2_4_2 reason: config fails restriction
# skipping config 64_2_4_4 reason: config fails restriction
# skipping config 64_2_4_8 reason: config fails restriction
# skipping config 64_2_8_1 reason: config fails restriction
# skipping config 64_2_8_2 reason: config fails restriction
# skipping config 64_2_8_4 reason: config fails restriction
# skipping config 64_2_8_8 reason: config fails restriction
# skipping config 64_4_1_1 reason: config fails restriction
# skipping config 64_4_1_2 reason: config fails restriction
# skipping config 64_4_1_4 reason: config fails restriction
# skipping config 64_4_1_8 reason: config fails restriction
# skipping config 64_4_2_1 reason: config fails restriction
# skipping config 64_4_2_2 reason: config fails restriction
# skipping config 64_4_2_4 reason: config fails restriction
# skipping config 64_4_2_8 reason: config fails restriction
# skipping config 64_4_4_1 reason: config fails restriction
# skipping config 64_4_4_2 reason: config fails restriction
# skipping config 64_4_4_4 reason: config fails restriction
# skipping config 64_4_4_8 reason: config fails restriction
# skipping config 64_4_8_1 reason: config fails restriction
# skipping config 64_4_8_2 reason: config fails restriction
# skipping config 64_4_8_4 reason: config fails restriction
# skipping config 64_4_8_8 reason: config fails restriction
# skipping config 64_8_1_1 reason: config fails restriction
# skipping config 64_8_1_2 reason: config fails restriction
# skipping config 64_8_1_4 reason: config fails restriction
# block_size_x=64, block_size_y=8, tile_size_x=1, tile_size_y=8, time=91.9946426392
# skipping config 64_8_2_1 reason: config fails restriction
# skipping config 64_8_2_2 reason: config fails restriction
# skipping config 64_8_2_4 reason: config fails restriction
# block_size_x=64, block_size_y=8, tile_size_x=2, tile_size_y=8, time=55.5250419617
# skipping config 64_8_4_1 reason: config fails restriction
# skipping config 64_8_4_2 reason: config fails restriction
# skipping config 64_8_4_4 reason: config fails restriction
# skipping config matmul_kernel_64_8_4_8 reason: too much shared memory used
# skipping config 64_8_8_1 reason: config fails restriction
# skipping config 64_8_8_2 reason: config fails restriction
# skipping config 64_8_8_4 reason: config fails restriction
# skipping config matmul_kernel_64_8_8_8 reason: too much shared memory used
# skipping config 64_16_1_1 reason: config fails restriction
# skipping config 64_16_1_2 reason: config fails restriction
# block_size_x=64, block_size_y=16, tile_size_x=1, tile_size_y=4, time=107.024052429
# skipping config 64_16_1_8 reason: config fails restriction
# skipping config 64_16_2_1 reason: config fails restriction
# skipping config 64_16_2_2 reason: config fails restriction
# block_size_x=64, block_size_y=16, tile_size_x=2, tile_size_y=4, time=64.8354492188
# skipping config 64_16_2_8 reason: config fails restriction
# skipping config 64_16_4_1 reason: config fails restriction
# skipping config 64_16_4_2 reason: config fails restriction
# skipping config matmul_kernel_64_16_4_4 reason: too much shared memory used
# skipping config 64_16_4_8 reason: config fails restriction
# skipping config 64_16_8_1 reason: config fails restriction
# skipping config 64_16_8_2 reason: config fails restriction
# skipping config matmul_kernel_64_16_8_4 reason: too much shared memory used
# skipping config 64_16_8_8 reason: config fails restriction
# skipping config 64_32_1_1 reason: config fails restriction
# skipping config 64_32_1_2 reason: too many threads per block
# skipping config 64_32_1_4 reason: config fails restriction
# skipping config 64_32_1_8 reason: config fails restriction
# skipping config 64_32_2_1 reason: config fails restriction
# skipping config 64_32_2_2 reason: too many threads per block
# skipping config 64_32_2_4 reason: config fails restriction
# skipping config 64_32_2_8 reason: config fails restriction
# skipping config 64_32_4_1 reason: config fails restriction
# skipping config 64_32_4_2 reason: too many threads per block
# skipping config 64_32_4_4 reason: config fails restriction
# skipping config 64_32_4_8 reason: config fails restriction
# skipping config 64_32_8_1 reason: config fails restriction
# skipping config 64_32_8_2 reason: too many threads per block
# skipping config 64_32_8_4 reason: config fails restriction
# skipping config 64_32_8_8 reason: config fails restriction
# best performing configuration: block_size_x=32, block_size_y=4, tile_size_x=4, tile_size_y=8, time=43.9385276794
